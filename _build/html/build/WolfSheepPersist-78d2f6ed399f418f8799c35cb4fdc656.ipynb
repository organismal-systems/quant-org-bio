# %%
import comm
comm.g_width = 32
comm.g_height = 32
comm.g_marker = 50
comm.psize = 125

# %%
import comm
comm.g_width = 64
comm.g_height = 64
comm.g_marker = 10
comm.psize = 125

# %%
import codes.WSP3
pg = codes.WSP3.setupWSP()
pg
# Out:
# Cannot show ipywidgets in text
