# %%
import comm
comm.g_width = 32
comm.g_height = 32
comm.g_marker = 50
comm.psize = 125

# %%
import codes.WSP3
pg = WSP3.setupWSP()
pg
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import codes.WSP3
#       2 pg = WSP3.setupWSP()
#       3 pg
#
# File ~/EBP/quant-org-bio/subrepos/spatial-dynamics/MesaWolfSheep/codes/WSP3.py:1
# ----> 1 from agents2 import GrassPatch, Sheep, Wolf
#       2 from mesa import Model
#       3 from mesa.datacollection import DataCollector
#
# ModuleNotFoundError: No module named 'agents2'
