# %% [markdown]
# # 🧮 A Mesa model of three trophically-linked popoulations
# To run this model, follow these four steps:
# 1. Set the parameters in the code box below:
#      - the size of the grid is set by the width and height parameters
#      - the size of the agents in the plot
#          - psize: the size of the grass patch
#          - marker: the size of wolves and sheep
#          -
#     Size in the plots may need to be adjusted to be visually clear if you make the grid very large or small.
# 2. Execute `>> Restart the kernel and run all cells`.
#     The first time you do this, check the `Do not ask again` box to speed things up later.
#    Ignore the pink warning.
# 4. When the blue bar appears, click on the box at the right-hand side.

# %%
import codes.WSPcomm
codes.WSPcomm.g_width = 32
codes.WSPcomm.g_height = 32
codes.WSPcomm.g_marker = 50
codes.WSPcomm.psize = 125

# %%
import codes.WSP3
pg = codes.WSP3.setupWSP()
pg
# Out:
# <div class="jupyter-widget-checks-container">
#     <script>
#         (function () {
#             console.log("Checking for jupyter-widgets extensions")
#             const inLab = window._JUPYTERLAB !== undefined;
#             const silent = jupyter_widget_checks_silent;
#             const containers = document.getElementsByClassName('jupyter-widget-checks-container');
#             const rootEl = containers[containers.length - 1];
#             const libraries = window.jupyter_widget_checks_libraries;
#
#             function getBaseUrl() {
#                 const labConfigData = document.getElementById("jupyter-config-data");
#                 if (labConfigData) {
#                     /* lab and Voila */
#                     return JSON.parse(labConfigData.textContent).baseUrl;
#                 }
#                 let base = document.body.dataset.baseUrl || document.baseURI;
#                 return base;
#             }
#
# ...

# %% [markdown]
# :::{figure} #wsp_1
# :placeholder: ./images/WSP_1.png
# :align: left
# :::
